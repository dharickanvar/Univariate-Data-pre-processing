# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull()
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    False   False  False  False  False  False  False     False     False
# 1    False   False  False  False  False  False  False     False     False
# 2    False   False  False  False  False  False  False     False     False
# 3    False   False  False  False  False  False  False     False     False
# 4    False   False  False  False  False  False  False     False     False
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210  False   False  False  False  False  False  False     False     False
# 211  False   False  False  False  False  False  False     False     False
# 212  False   False  False  False  False  False  False     False     False
# 213  False   False  False  False  False  False  False     False     False
# 214  False   False  False  False  False  False  False     False     False
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#1)Replace the missing value with central tendenacy Mean,Median,Mode
#2)Entire row delete
#3)Respective to the problem,replace with missing values (only this is appiicabke for this dataset since other 3 types will come that without placed employee get salary or salary row will be deleted.)
#4)Consider this is a semi-supervised, create a model, so that we can predict the missing values.

# %%
dataset.isna()
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    False   False  False  False  False  False  False     False     False
# 1    False   False  False  False  False  False  False     False     False
# 2    False   False  False  False  False  False  False     False     False
# 3    False   False  False  False  False  False  False     False     False
# 4    False   False  False  False  False  False  False     False     False
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210  False   False  False  False  False  False  False     False     False
# 211  False   False  False  False  False  False  False     False     False
# 212  False   False  False  False  False  False  False     False     False
# 213  False   False  False  False  False  False  False     False     False
# 214  False   False  False  False  False  False  False     False     False
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#Note dataset.isna().sum() and dataset.isnull.sum() are give the same result

# %%
#3) for the missing values to be filled with fillna

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
#Note above line will fill the none values to 0 in the original dataset

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#2) Delete the entire row

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Note dropna is used to delete the nan values row will be deleted in previous 215x15 now 148x15

# %%
#Even though Mean,Median,Mode not suitable for this model just trying for the future use

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#now not place candidates also getting salary since this is wrong method but use to know how to use this type of method so using

# %%
dataset["salary"].fillna(dataset["salary"].median(),inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset["salary"].fillna(dataset["salary"].mode(),inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Since for one columns is ok if it is may colums we will use imputer

# %%
#Since getting error in below due to quantitative data is present in dataset getting error to avoid that calling qual,quan fun

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanqual(dataset)
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
#so that we are taking quan,qual fun in dataset previouslly done and taken the quan values from dataset and now place the dataswt[quan]in imputer

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
imp
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
#Since it is not worked we have to give it to another variable here done with transform

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])

# %%
df
# Out:
# array([[1.000e+00, 6.700e+01, 9.100e+01, ..., 5.500e+01, 5.880e+01,
#         2.700e+05],
#        [2.000e+00, 7.933e+01, 7.833e+01, ..., 8.650e+01, 6.628e+01,
#         2.000e+05],
#        [3.000e+00, 6.500e+01, 6.800e+01, ..., 7.500e+01, 5.780e+01,
#         2.500e+05],
#        ...,
#        [2.130e+02, 6.700e+01, 6.700e+01, ..., 5.900e+01, 6.972e+01,
#         2.950e+05],
#        [2.140e+02, 7.400e+01, 6.600e+01, ..., 7.000e+01, 6.023e+01,
#         2.040e+05],
#        [2.150e+02, 6.200e+01, 5.800e+01, ..., 8.900e+01, 6.022e+01,
#         0.000e+00]])

# %%
#to change the values view in table proceeding with DataFrame for quan

# %%
df=pd.DataFrame(df, columns = quan)

# %%
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
#There is no nan values in the above quan set

# %%
#now merging two dataframes in pandas for normal distribution note:cate is categorical data

# %%
cate=dataset[qual]

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two)
# Out:
# C:\Users\hp\.conda\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
preprocessed
# Out:
#      degree_p   degree_t  etest_p gender   hsc_b  hsc_p     hsc_s  mba_p  \
# 0       58.00        NaN     55.0    NaN     NaN  91.00       NaN  58.80
# 1       77.48        NaN     86.5    NaN     NaN  78.33       NaN  66.28
# 2       64.00        NaN     75.0    NaN     NaN  68.00       NaN  57.80
# 3       52.00        NaN     66.0    NaN     NaN  52.00       NaN  59.43
# 4       73.30        NaN     96.8    NaN     NaN  73.60       NaN  55.50
# ..        ...        ...      ...    ...     ...    ...       ...    ...
# 210       NaN  Comm&Mgmt      NaN      M  Others    NaN  Commerce    NaN
# 211       NaN   Sci&Tech      NaN      M  Others    NaN   Science    NaN
# 212       NaN  Comm&Mgmt      NaN      M  Others    NaN  Commerce    NaN
# 213       NaN  Comm&Mgmt      NaN      F  Others    NaN  Commerce    NaN
# 214       NaN  Comm&Mgmt      NaN      M  Others    NaN   Science    NaN
#
#        salary  sl_no specialisation    ssc_b  ssc_p      status workex
# ...

# %%
#Actually here row wise is merged that's why getting Nan values to avoid that merge using column wise give axis=1

# %%
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
preprocessed.isnull()
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary  gender  ssc_b  \
# 0    False  False  False     False    False  False   False   False  False
# 1    False  False  False     False    False  False   False   False  False
# 2    False  False  False     False    False  False   False   False  False
# 3    False  False  False     False    False  False   False   False  False
# 4    False  False  False     False    False  False   False   False  False
# ..     ...    ...    ...       ...      ...    ...     ...     ...    ...
# 210  False  False  False     False    False  False   False   False  False
# 211  False  False  False     False    False  False   False   False  False
# 212  False  False  False     False    False  False   False   False  False
# 213  False  False  False     False    False  False   False   False  False
# 214  False  False  False     False    False  False   False   False  False
#
#      hsc_b  hsc_s  degree_t  workex  specialisation  status
# ...

# %%
#to know exactly the value

# %%
preprocessed.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
#now our dataset is clear and no null values. Since we want this dataset to use in normal distribution
#saving this data set using preprocessed.to_csv("Preplacementdata.csv",index=False) here index=false denote no duplicate will create

# %%
preprocessed.to_csv("Preplacementdata.csv",index=False)
